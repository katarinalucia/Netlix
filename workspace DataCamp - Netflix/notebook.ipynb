# %% [markdown]
# ![Movie popcorn on red background](redpopcorn.jpg)

# %% [markdown]
# **Netflix**! What started in 1997 as a DVD rental service has since exploded into one of the largest entertainment and media companies.
#
# Given the large number of movies and series available on the platform, it is a perfect opportunity to flex your exploratory data analysis skills and dive into the entertainment industry. Our friend has also been brushing up on their Python skills and has taken a first crack at a CSV file containing Netflix data. They believe that the average duration of movies has been declining. Using your friends initial research, you'll delve into the Netflix data to see if you can determine whether movie lengths are actually getting shorter and explain some of the contributing factors, if any.
#
# You have been supplied with the dataset `netflix_data.csv` , along with the following table detailing the column names and descriptions:
#
# ## The data
# ### **netflix_data.csv**
# | Column | Description |
# |--------|-------------|
# | `show_id` | The ID of the show |
# | `type` | Type of show |
# | `title` | Title of the show |
# | `director` | Director of the show |
# | `cast` | Cast of the show |
# | `country` | Country of origin |
# | `date_added` | Date added to Netflix |
# | `release_year` | Year of Netflix release |
# | `duration` | Duration of the show in minutes |
# | `description` | Description of the show |
# | `genre` | Show genre |

# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Start coding!

# %%
netflix_df = pd.read_csv ('netflix_data.csv')

# %%
netflix_df.head(10)
# Out:
#   show_id  ...             genre
# 0      s1  ...  International TV
# 1      s2  ...            Dramas
# 2      s3  ...     Horror Movies
# 3      s4  ...            Action
# 4      s5  ...            Dramas
# 5      s6  ...  International TV
# 6      s7  ...     Horror Movies
# 7      s8  ...            Dramas
# 8      s9  ...     Horror Movies
# 9     s10  ...     Horror Movies
#
# [10 rows x 11 columns]

# %%
netflix_df['type'].unique()
# Out:
# array(['TV Show', 'Movie'], dtype=object)

# %%
netflix_subset = netflix_df[netflix_df['type'] == 'Movie']

# %%
netflix_subset.head()
# Out:
#   show_id  ...          genre
# 1      s2  ...         Dramas
# 2      s3  ...  Horror Movies
# 3      s4  ...         Action
# 4      s5  ...         Dramas
# 6      s7  ...  Horror Movies
#
# [5 rows x 11 columns]

# %%
netflix_movies = netflix_subset[["title", "country", "genre", "release_year", "duration"]]

# %%
netflix_movies.head()
# Out:
#    title        country          genre  release_year  duration
# 1   7:19         Mexico         Dramas          2016        93
# 2  23:59      Singapore  Horror Movies          2011        78
# 3      9  United States         Action          2009        80
# 4     21  United States         Dramas          2008       123
# 6    122          Egypt  Horror Movies          2019        95

# %%
netflix_movies['duration'].unique()
# Out:
# array([ 93,  78,  80, 123,  95, 119, 118, 143, 103,  89,  91, 149, 144,
#        124,  87, 110, 128, 117, 100,  84,  99,  90, 102, 104, 105,  56,
#        125,  81,  97, 106, 107, 109,  44,  75, 101,  37, 113, 114, 130,
#         94, 140, 135,  82,  70, 121,  92, 164,  53,  83, 116,  86, 120,
#         96, 126, 129,  77, 137, 148,  28, 122, 176,  85,  22,  68, 111,
#         29, 142, 168,  21,  59,  20,  98, 108,  76,  26, 156,  30,  57,
#        150, 133, 115, 154, 127, 146, 136,  88, 131,  24, 112,  74,  63,
#         38,  25, 174,  60, 153, 158, 151, 162,  54,  51,  69,  64, 147,
#         42,  79,  40,  45, 172,  10, 163,  55,  72,  61,  71, 160, 171,
#         48, 139, 157,  15,  65, 134, 161,  62, 186,  49,  73,  58, 165,
#        166, 138, 159, 141, 132,  52,  67,  34,  66, 312, 180,  47, 155,
#         14, 177,  11,   9,  46, 145,   8,  12,  43,  50,  23, 185, 200,
#        169,  27, 170, 196,  33, 181, 204,  32,  35, 167, 179, 193,  13,
#        214,  17, 173, 192, 209, 187,  41, 182, 224, 233, 189, 152,  19,
#        208, 237,  31, 178, 230, 194, 228, 195,   3,  16,   5,  18, 205,
#        190,  36, 201, 253, 203, 191])

# %%
short_movies = netflix_movies[netflix_movies['duration']<60]

# %%
short_movies.head()
# Out:
#                                                  title  ... duration
# 35                                           #Rucker50  ...       56
# 55                 100 Things to do Before High School  ...       44
# 67   13TH: A Conversation with Oprah Winfrey & Ava ...  ...       37
# 101                                  3 Seconds Divorce  ...       53
# 146                                     A 3 Minute Hug  ...       28
#
# [5 rows x 5 columns]

# %%
short_movies['genre'].unique()
# Out:
# array(['Documentaries', 'Uncategorized', 'Children', 'Stand-Up',
#        'Comedies', 'Dramas', 'International Movies', 'Action', 'Music',
#        'Classic Movies', 'Anime Features', 'Horror Movies'], dtype=object)

# %%
colors = []

for i, row in netflix_movies.iterrows() :
    if row ['genre'] == 'Documentaries':
        colors.append("grey")
    elif row ['genre'] == 'Uncategorized':
        colors.append("cyan")
    elif row ['genre'] == 'Children':
        colors.append("yellow")
    elif row ['genre'] == 'Stand-Up':
        colors.append("green")
    elif row ['genre'] == 'Comedies':
        colors.append("orange")
    elif row ['genre'] == 'Dramas':
        colors.append("pink")
    elif row ['genre'] == 'International Movies':
        colors.append("blue")
    elif row ['genre'] == 'Action':
        colors.append("red")
    elif row ['genre'] ==  'Music':
        colors.append("purple")
    elif row ['genre'] == 'Classic Movies':
        colors.append("white")
    elif row ['genre'] == 'Anime Features':
        colors.append("brown")
    else :
        colors.append("black")
        
# colors = list(set(colors))
colors[:10]
print(colors)


# # Iterate over rows of netflix_movies
# for label, row in netflix_movies.iterrows() :
#     if row["genre"] == "Children" :
#         colors.append("red")
#     elif row["genre"] == "Documentaries" :
#         colors.append("blue")
#     elif row["genre"] == "Stand-Up":
#         colors.append("green")
#     else:
#         colors.append("black")
        
# # Inspect the first 10 values in your list        
# colors[:10]
# Out:
# ['pink', 'black', 'red', 'pink', 'black', 'pink', 'black', 'black', 'pink', 'grey', 'black', 'pink', 'pink', 'orange', 'black', 'pink', 'red', 'pink', 'pink', 'grey', 'black', 'grey', 'grey', 'pink', 'pink', 'orange', 'orange', 'grey', 'orange', 'orange', 'orange', 'orange', 'black', 'orange', 'pink', 'red', 'pink', 'pink', 'orange', 'orange', 'red', 'grey', 'pink', 'cyan', 'grey', 'pink', 'pink', 'pink', 'black', 'black', 'grey', 'cyan', 'red', 'black', 'grey', 'red', 'orange', 'pink', 'pink', 'black', 'black', 'orange', 'orange', 'grey', 'blue', 'black', 'pink', 'orange', 'red', 'red', 'red', 'pink', 'red', 'grey', 'orange', 'red', 'pink', 'pink', 'pink', 'orange', 'grey', 'orange', 'orange', 'red', 'pink', 'pink', 'pink', 'blue', 'grey', 'yellow', 'orange', 'orange', 'pink', 'red', 'orange', 'orange', 'orange', 'orange', 'orange', 'pink', 'orange', 'pink', 'red', 'red', 'pink', 'black', 'orange', 'pink', 'orange', 'pink', 'orange', 'pink', 'yellow', 'grey', 'yellow', 'orange', 'pink', 'pink', 'pink', 'red', 'orange', 'yellow', 'orange', 'red', 'pink', 'yellow', 'yellow', 'yellow', 'cyan', 'yellow', 'yellow', 'white', 'pink', 'yellow', 'pink', 'grey', 'pink', 'cyan', 'red', 'pink', 'orange', 'pink', 'orange', 'yellow', 'yellow', 'yellow', 'grey', 'grey', 'orange', 'black', 'pink', 'yellow', 'orange', 'grey', 'black', 'pink', 'grey', 'grey', 'pink', 'grey', 'pink', 'orange', 'orange', 'pink', 'pink', 'grey', 'grey', 'pink', 'orange', 'pink', 'pink', 'pink', 'pink', 'grey', 'yellow', 'orange', 'green', 'blue', 'pink', 'grey', 'pink', 'orange', 'yellow', 'brown', 'pink', 'pink', 'pink', 'pink', 'yellow', 'pink', 'pink', 'grey', 'orange', 'orange', 'yellow', 'orange', 'yellow', 'pink', 'purple', 'orange', 'blue', 'pink', 'red', 'grey', 'brown', 'yellow', 'yellow', 'pink', 'black', 'red', 'pink', 'orange', 'orange', 'orange', 'red', 'pink', 'blue', 'pink', 'pink', 'pink', 'pink', 'orange', 'black', 'orange', 'pink', 'pink', 'red', 'grey', 'pink', 'orange', 'yellow', 'orange', 'orange', 'pink', 'orange', 'blue', 'pink', 'pink', 'pink', 'red', 'red', 'yellow', 'red', 'red', 'pink', 'green', 'green', 'pink', 'red', 'green', 'orange', 'green', 'pink', 'red', 'black', 'pink', 'orange', 'blue', 'green', 'pink', 'grey', 'grey', 'grey', 'grey', 'pink', 'pink', 'pink', 'red', 'pink', 'cyan', 'pink', 'green', 'black', 'pink', 'grey', 'pink', 'orange', 'pink', 'blue', 'red', 'orange', 'orange', 'pink', 'orange', 'blue', 'red', 'orange', 'green', 'orange', 'pink', 'pink', 'yellow', 'green', 'grey', 'orange', 'green', 'orange', 'white', 'white', 'grey', 'pink', 'red', 'green', 'green', 'orange', 'grey', 'red', 'white', 'orange', 'grey', 'red', 'yellow', 'yellow', 'grey', 'pink', 'orange', 'red', 'pink', 'yellow', 'blue', 'yellow', 'grey', 'black', 'orange', 'black', 'pink', 'red', 'orange', 'orange', 'pink', 'orange', 'pink', 'pink', 'orange', 'pink', 'pink', 'black', 'yellow', 'yellow', 'grey', 'grey', 'red', 'orange', 'blue', 'grey', 'grey', 'pink', 'orange', 'red', 'pink', 'pink', 'grey', 'grey', 'red', 'pink', 'grey', 'grey', 'grey', 'grey', 'grey', 'black', 'red', 'pink', 'pink', 'grey', 'grey', 'orange', 'orange', 'pink', 'pink', 'green', 'orange', 'pink', 'grey', 'green', 'green', 'grey', 'yellow', 'yellow', 'yellow', 'yellow', 'orange', 'white', 'orange', 'pink', 'pink', 'pink', 'pink', 'orange', 'orange', 'orange', 'blue', 'pink', 'orange', 'pink', 'pink', 'orange', 'red', 'orange', 'black', 'black', 'grey', 'grey', 'pink', 'red', 'pink', 'red', 'yellow', 'yellow', 'black', 'orange', 'pink', 'red', 'pink', 'pink', 'yellow', 'red', 'black', 'red', 'green', 'pink', 'pink', 'yellow', 'pink', 'pink', 'red', 'orange', 'yellow', 'green', 'green', 'orange', 'red', 'grey', 'pink', 'grey', 'pink', 'grey', 'black', 'black', 'red', 'red', 'pink', 'green', 'yellow', 'pink', 'orange', 'green', 'grey', 'orange', 'red', 'blue', 'green', 'orange', 'yellow', 'pink', 'pink', 'black', 'orange', 'pink', 'pink', 'red', 'grey', 'red', 'black', 'orange', ' ...

# %%
fig = plt.figure(figsize=(12,8))
plt.scatter(netflix_movies.release_year, netflix_movies.duration, c=colors)
plt.xlabel("Release year")
plt.ylabel("Duration (min)")
plt.title("Movie Duration by Year of Release")
plt.show()

# %%
answer = "maybe"
